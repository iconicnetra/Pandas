# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
# Out:
# C:\Users\netra\AppData\Local\Temp\ipykernel_27004\585249826.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = {
    "Player": ["Messi", "Ronaldo", "Neymar", "MBappe", "Salah"], 
    "Goals0": np.random.randint(0, 30, size=5),
    "Assists": np.random.randint(0, 20, size = 5), 
    "YellowCards": np.random.randint(0, 10, size=5), 
    "Redcards": np.random.randint(0, 3, size=5)
}

df = pd.DataFrame(data)
df.hist() 
plt.show()

# %%
import modin.pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import modin.pandas as pd
#
# ModuleNotFoundError: No module named 'modin'
