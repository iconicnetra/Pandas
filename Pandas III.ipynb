# %%
import pandas as pd

# %%
#PANDAS by Examples

# %%
df = pd.read_csv("E:\Python\Pandas_Project\Data\data.csv")
df
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         1             rarely
# 1    Female          55         2          sometimes
# 2      male          65         3             always
# 3    Female          79         4             rarely
# 4      male          67         1              often
# ..      ...         ...       ...                ...
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 0    interactive whiteboards,     yes        43               Android   17
# 1            educational apps     yes        41                   IOS   18
# 2            online platforms     yes        45               Windows   18
# ...

# %%
df.head()
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# 0     yes        43               Android   17   Metropolitan City      Hindu
# 1     yes        41                   IOS   18     Submetropolitan  Christian
# 2     yes        45               Windows   18        Municipality    Buddism
# 3      no        40                others   19  Rural Municipality     Muslim
# 4      no        44               Android   17   Metropolitan City      other

# %%
df.head(1)
# Out:
#   Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0   male          51         1             rarely  interactive whiteboards,
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age    Residental_Area Religion
# 0     yes        43               Android   17  Metropolitan City    Hindu

# %%
df.head(3)
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age    Residental_Area   Religion
# 0     yes        43               Android   17  Metropolitan City      Hindu
# 1     yes        41                   IOS   18    Submetropolitan  Christian
# 2     yes        45               Windows   18       Municipality    Buddism

# %%
df.tail(10)
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 190    male          50         2              often
# 191  Female          70         4             always
# 192    male          50         2              often
# 193  Female          57         5             always
# 194    male          68         2              often
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 190          educational apps      no        37               Windows   15
# 191          online platforms     yes        43                others   14
# 192      multimedia resources      no        34               Android   12
# 193  interactive whiteboards,     yes        46                   IOS   15
# ...

# %%
df.tail(20)
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 180    male          76         5             always
# 181  Female          64         2              often
# 182    male          56         4             always
# 183  Female          52         5          sometimes
# 184    male          58         2              often
# 185  Female          55         3              often
# 186    male          49         4             always
# 187  Female          68         5              often
# 188    male          65         6             always
# 189  Female          75         2          sometimes
# 190    male          50         2              often
# 191  Female          70         4             always
# 192    male          50         2              often
# 193  Female          57         5             always
# 194    male          68         2              often
# 195  Female          68         5             always
# 196    male          54         4              often
# ...

# %% [markdown]
# Activities

# %%
#How may elements does this dataframe have? 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 200 non-null    object
#  1   Marks_Math             200 non-null    int64
#  2   Time_ICT               200 non-null    int64
#  3   ICT_Based_Pedagogy     200 non-null    object
#  4   ICT_Tools              200 non-null    object
#  5   TPD_ICT                200 non-null    object
#  6   CS_Marks               200 non-null    int64
#  7   Operating_system_Used  200 non-null    object
#  8   Age                    200 non-null    int64
#  9   Residental_Area        200 non-null    object
#  10  Religion               200 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 17.3+ KB

# %%
df.shape #Rows and columns
# Out:
# (200, 11)

# %%
#What is t he highest possible value of the word
df['Age'].max()
# Out:
# 20

# %%
df.max() #For maximum value of the dataframe
# Out:
# Gender                               male
# Marks_Math                             94
# Time_ICT                                7
# ICT_Based_Pedagogy              sometimes
# ICT_Tools                online platforms
# TPD_ICT                               yes
# CS_Marks                               49
# Operating_system_Used              others
# Age                                    20
# Residental_Area           Submetropolitan
# Religion                            other
# dtype: object

# %%
df.describe()
# Out:
#        Marks_Math    Time_ICT    CS_Marks         Age
# count  200.000000  200.000000  200.000000  200.000000
# mean    63.725000    3.355000   41.165000   14.900000
# std     11.799386    1.533209    3.168275    1.883544
# min     33.000000    1.000000   33.000000   12.000000
# 25%     56.000000    2.000000   39.000000   13.000000
# 50%     64.000000    3.000000   41.000000   15.000000
# 75%     72.000000    5.000000   43.000000   16.000000
# max     94.000000    7.000000   49.000000   20.000000

# %%
df.min()
# Out:
# Gender                              Female
# Marks_Math                              33
# Time_ICT                                 1
# ICT_Based_Pedagogy                  always
# ICT_Tools                 educational apps
# TPD_ICT                                 no
# CS_Marks                                33
# Operating_system_Used                    5
# Age                                     12
# Residental_Area          Metropolitan City
# Religion                           Buddism
# dtype: object

# %%
df["Age"]
# Out:
# 0      17
# 1      18
# 2      18
# 3      19
# 4      17
#        ..
# 195    15
# 196    14
# 197    20
# 198    17
# 199    18
# Name: Age, Length: 200, dtype: int64

# %% [markdown]
# Selection of Data

# %%
df.head(10)
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
# 5  Female          37         2          sometimes          educational apps
# 6  Female          36         3             rarely  interactive whiteboards,
# 7  Female          48         4             always          online platforms
# 8  Female          68         1          sometimes          educational apps
# 9  Female          72         3             always          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# ...

# %%
#Column Selectioni
df["Marks_Math"]
# Out:
# 0      51
# 1      55
# 2      65
# 3      79
# 4      67
#        ..
# 195    68
# 196    54
# 197    72
# 198    52
# 199    54
# Name: Marks_Math, Length: 200, dtype: int64

# %%
df["CS_Marks"]
# Out:
# 0      43
# 1      41
# 2      45
# 3      40
# 4      44
#        ..
# 195    44
# 196    45
# 197    41
# 198    39
# 199    37
# Name: CS_Marks, Length: 200, dtype: int64

# %%
df["ICT_Based_Pedagogy"]
# Out:
# 0         rarely
# 1      sometimes
# 2         always
# 3         rarely
# 4          often
#          ...
# 195       always
# 196        often
# 197       always
# 198        often
# 199       always
# Name: ICT_Based_Pedagogy, Length: 200, dtype: object

# %%
#Slicing and Selecting Rows
df[0:3] #Provides first three rows Alternative of df.head(3)
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age    Residental_Area   Religion
# 0     yes        43               Android   17  Metropolitan City      Hindu
# 1     yes        41                   IOS   18    Submetropolitan  Christian
# 2     yes        45               Windows   18       Municipality    Buddism

# %%
#Selecting multiple columns
df[[
    "Age", "CS_Marks", "Gender"
]]
# Out:
#      Age  CS_Marks  Gender
# 0     17        43    male
# 1     18        41  Female
# 2     18        45    male
# 3     19        40  Female
# 4     17        44    male
# ..   ...       ...     ...
# 195   15        44  Female
# 196   14        45    male
# 197   20        41    male
# 198   17        39  Female
# 199   18        37    male
#
# [200 rows x 3 columns]

# %%
df[[
    "ICT_Based_Pedagogy", "Gender", "Marks_Math", "Operating_system_Used", "Age"
]]
# Out:
#     ICT_Based_Pedagogy  Gender  Marks_Math Operating_system_Used  Age
# 0               rarely    male          51               Android   17
# 1            sometimes  Female          55                   IOS   18
# 2               always    male          65               Windows   18
# 3               rarely  Female          79                others   19
# 4                often    male          67               Android   17
# ..                 ...     ...         ...                   ...  ...
# 195             always  Female          68                others   15
# 196              often    male          54               Android   14
# 197             always    male          72                   IOS   20
# 198              often  Female          52               Windows   17
# 199             always    male          54                others   18
#
# [200 rows x 5 columns]

# %%
#Selection by Level
df.loc[:, ["Age", "Gender"]]
# Out:
#      Age  Gender
# 0     17    male
# 1     18  Female
# 2     18    male
# 3     19  Female
# 4     17    male
# ..   ...     ...
# 195   15  Female
# 196   14    male
# 197   20    male
# 198   17  Female
# 199   18    male
#
# [200 rows x 2 columns]

# %%
df.loc[0:10, ['Age', 'Gender']] #Selects only 11 rows of the data
# Out:
#     Age  Gender
# 0    17    male
# 1    18  Female
# 2    18    male
# 3    19  Female
# 4    17    male
# 5    16  Female
# 6    15  Female
# 7    12  Female
# 8    13  Female
# 9    17  Female
# 10   18    male

# %%
df.loc[0:20, ['Age', 'Gender', 'Marks_Math', 'CS_Marks']]
# Out:
#     Age  Gender  Marks_Math  CS_Marks
# 0    17    male          51        43
# 1    18  Female          55        41
# 2    18    male          65        45
# 3    19  Female          79        40
# 4    17    male          67        44
# 5    16  Female          37        43
# 6    15  Female          36        48
# 7    12  Female          48        38
# 8    13  Female          68        40
# 9    17  Female          72        40
# 10   18    male          45        43
# 11   18    male          47        39
# 12   16    male          54        42
# 13   15    male          70        42
# 14   14    male          58        40
# 15   12    male          85        43
# 16   15  Female          60        44
# 17   12    male          62        43
# 18   13  Female          75        40
# 19   14  Female          70        40
# 20   15    male          76        39

# %%
#Selection by Position
df.iloc[10] #Selects the 11th rows of the data
# Out:
# Gender                                 male
# Marks_Math                               45
# Time_ICT                                  4
# ICT_Based_Pedagogy                    often
# ICT_Tools                  online platforms
# TPD_ICT                                  no
# CS_Marks                                 43
# Operating_system_Used               Windows
# Age                                      18
# Residental_Area          Rural Municipality
# Religion                              Hindu
# Name: 10, dtype: object

# %%
df.head(20)
# Out:
#     Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0     male          51         1             rarely  interactive whiteboards,
# 1   Female          55         2          sometimes          educational apps
# 2     male          65         3             always          online platforms
# 3   Female          79         4             rarely          online platforms
# 4     male          67         1              often          online platforms
# 5   Female          37         2          sometimes          educational apps
# 6   Female          36         3             rarely  interactive whiteboards,
# 7   Female          48         4             always          online platforms
# 8   Female          68         1          sometimes          educational apps
# 9   Female          72         3             always          online platforms
# 10    male          45         4              often          online platforms
# ...

# %%
df.iloc[3:5] #Selects 4th and 5th rows 
#Note: 5 means 6th row which will be excluded in the selection
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy         ICT_Tools TPD_ICT  \
# 3  Female          79         4             rarely  online platforms      no
# 4    male          67         1              often  online platforms      no
#
#    CS_Marks Operating_system_Used  Age     Residental_Area Religion
# 3        40                others   19  Rural Municipality   Muslim
# 4        44               Android   17   Metropolitan City    other

# %%
df.loc[3:5] #Loc function includes the last attribute that is 6th row of the dataframe
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy         ICT_Tools TPD_ICT  \
# 3  Female          79         4             rarely  online platforms      no
# 4    male          67         1              often  online platforms      no
# 5  Female          37         2          sometimes  educational apps     yes
#
#    CS_Marks Operating_system_Used  Age     Residental_Area Religion
# 3        40                others   19  Rural Municipality   Muslim
# 4        44               Android   17   Metropolitan City    other
# 5        43                   IOS   16        Municipality    Hindu

# %%
df.iloc[2:5, 0:5] #Number of rows and columns 
#Only three rows 3rd, 4th, & 5th rows and columns from 0 to 4 (5 columns)
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy         ICT_Tools
# 2    male          65         3             always  online platforms
# 3  Female          79         4             rarely  online platforms
# 4    male          67         1              often  online platforms

# %%
#Slicing Rows Explicitly
df.iloc[1:5, :]
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy         ICT_Tools TPD_ICT  \
# 1  Female          55         2          sometimes  educational apps     yes
# 2    male          65         3             always  online platforms     yes
# 3  Female          79         4             rarely  online platforms      no
# 4    male          67         1              often  online platforms      no
#
#    CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# 1        41                   IOS   18     Submetropolitan  Christian
# 2        45               Windows   18        Municipality    Buddism
# 3        40                others   19  Rural Municipality     Muslim
# 4        44               Android   17   Metropolitan City      other

# %%
#Getting value explicity
df.iloc[2, 2] #selects element of 3rd rows and 3rd column
df.iloc[3, 3] #select element of 4th row and 4th column
# Out:
# 'rarely'

# %%
df.head()
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# 0     yes        43               Android   17   Metropolitan City      Hindu
# 1     yes        41                   IOS   18     Submetropolitan  Christian
# 2     yes        45               Windows   18        Municipality    Buddism
# 3      no        40                others   19  Rural Municipality     Muslim
# 4      no        44               Android   17   Metropolitan City      other

# %% [markdown]
# Copying the dataframe

# %%
df1 = df.copy()
df1
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         1             rarely
# 1    Female          55         2          sometimes
# 2      male          65         3             always
# 3    Female          79         4             rarely
# 4      male          67         1              often
# ..      ...         ...       ...                ...
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 0    interactive whiteboards,     yes        43               Android   17
# 1            educational apps     yes        41                   IOS   18
# 2            online platforms     yes        45               Windows   18
# ...

# %%
#Conditional Selection
df[df['Marks_Math']>80] #Selects the rows values which has greater than 80 in Marks in Math Column
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 15     male          85         1              often
# 21     male          89         3             always
# 24   Female          84         3              often
# 28   Female          83         2              often
# 48     male          82         5              often
# 59     male          94         2          sometimes
# 68     male          87         1          sometimes
# 87   Female          85         3             rarely
# 90     male          81         3             always
# 142  Female          83         5          sometimes
# 145  Female          84         5             rarely
# 150    male          85         5          sometimes
# 156  Female          83         4             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 15           educational apps      no        43                others   12
# ...

# %%
df[df['Time_ICT']>=7]
# Out:
#     Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy             ICT_Tools  \
# 127   male          70         7             rarely  multimedia resources
#
#     TPD_ICT  CS_Marks Operating_system_Used  Age Residental_Area Religion
# 127      no        39               Android   13    Municipality    other

# %%
df[df["Gender"] == "male"] #Selects the data which has male in the Gender column
# Out:
#     Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0     male          51         1             rarely  interactive whiteboards,
# 2     male          65         3             always          online platforms
# 4     male          67         1              often          online platforms
# 10    male          45         4              often          online platforms
# 11    male          47         2          sometimes      multimedia resources
# ..     ...         ...       ...                ...                       ...
# 192   male          50         2              often      multimedia resources
# 194   male          68         2              often  interactive whiteboards,
# 196   male          54         4              often          educational apps
# 197   male          72         2             always      multimedia resources
# 199   male          54         3             always      multimedia resources
#
# ...

# %%
df[df["Residental_Area"]=="Metropolitan City"]
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         1             rarely
# 4      male          67         1              often
# 11     male          47         2          sometimes
# 17     male          62         4             always
# 23     male          73         2          sometimes
# 26   Female          63         4             always
# 35   Female          79         2             rarely
# 39     male          60         4             always
# 46     male          61         4             rarely
# 53     male          61         2              often
# 62     male          71         4          sometimes
# 66     male          61         5              often
# 75   Female          62         5             rarely
# 79   Female          68         3             rarely
# 86     male          73         5             always
# 93   Female          74         3             always
# 102    male          60         4              often
# ...

# %%
df[df["Operating_system_Used"]=="Android"]
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         1             rarely
# 4      male          67         1              often
# 8    Female          68         1          sometimes
# 12     male          54         3              often
# 16   Female          60         2          sometimes
# 20     male          76         4          sometimes
# 24   Female          84         3              often
# 28   Female          83         2              often
# 32     male          54         3             always
# 34   Female          43         5              often
# 36   Female          64         4          sometimes
# 40   Female          72         3             rarely
# 44   Female          37         2          sometimes
# 48     male          82         5              often
# 52     male          72         5          sometimes
# 55   Female          70         2             always
# 57   Female          68         4          sometimes
# ...

# %%
df.iat[0, 2] = 4 #Selects and replace the value (0 row and third column)

# %%
df
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         4             rarely
# 1    Female          55         2          sometimes
# 2      male          65         3             always
# 3    Female          79         4             rarely
# 4      male          67         1              often
# ..      ...         ...       ...                ...
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 0    interactive whiteboards,     yes        43               Android   17
# 1            educational apps     yes        41                   IOS   18
# 2            online platforms     yes        45               Windows   18
# ...

# %% [markdown]
# Statistics in Pandas

# %%
df['Age'].mean()
# Out:
# 14.9

# %%
df["CS_Marks"].mean()
# Out:
# 41.165

# %%
df["Marks_Math"].mean()
# Out:
# 63.725

# %%
df["Marks_Math"].median()
# Out:
# 64.0

# %%
df["Gender"].count()
# Out:
# 200

# %%
df[df["Gender"]=="male"].count()
# Out:
# Gender                   98
# Marks_Math               98
# Time_ICT                 98
# ICT_Based_Pedagogy       98
# ICT_Tools                98
# TPD_ICT                  98
# CS_Marks                 98
# Operating_system_Used    98
# Age                      98
# Residental_Area          98
# Religion                 98
# dtype: int64

# %%
df.loc[df['Marks_Math']==50]   #Provides the rows data which has 50 in Marks in mathematics
# Out:
#     Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy             ICT_Tools  \
# 70    male          50         6             rarely      educational apps
# 190   male          50         2              often      educational apps
# 192   male          50         2              often  multimedia resources
#
#     TPD_ICT  CS_Marks Operating_system_Used  Age  Residental_Area Religion
# 70      yes        42                   IOS   15     Municipality  Buddism
# 190      no        37               Windows   15     Municipality   Muslim
# 192      no        34               Android   12  Submetropolitan    Hindu

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    102
# male       98
# Name: count, dtype: int64

# %%
df.loc[df["Residental_Area"]=="Municipality"].shape
# Out:
# (57, 11)

# %%
df.sort_values(by = 'Marks_Math', ascending=False)
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 59     male          94         2          sometimes
# 21     male          89         3             always
# 68     male          87         1          sometimes
# 15     male          85         1              often
# 150    male          85         5          sometimes
# ..      ...         ...       ...                ...
# 22   Female          37         1             always
# 5    Female          37         2          sometimes
# 44   Female          37         2          sometimes
# 6    Female          36         3             rarely
# 89   Female          33         5              often
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 59           online platforms      no        43               Windows   16
# 21   interactive whiteboards,     yes        42                   IOS   14
# 68           educational apps     yes        45               Android   13
# ...

# %%
df.groupby("Gender", observed=False).size()
# Out:
# Gender
# Female    102
# male       98
# dtype: int64

# %%
df.groupby("ICT_Tools", observed=False).size()
# Out:
# ICT_Tools
# educational apps            42
# interactive whiteboards,    13
# multimedia resources        61
# online platforms            84
# dtype: int64

# %%
df.groupby("Residental_Area", observed=False).size()
# Out:
# Residental_Area
# Metropolitan City     32
# Municipality          57
# Rural Municipality    58
# Submetropolitan       53
# dtype: int64
