# %%
import pandas as pd

# %%
data1 = {'name': ['Netra', 'Kumar', 'Shristi', 'Binayak'], 
         'age': [30, 25, 33, 54], 
         'country': ['Nepal', 'USA', 'UAE', 'India']}
print(data1)
# Out:
# {'name': ['Netra', 'Kumar', 'Shristi', 'Binayak'], 'age': [30, 25, 33, 54], 'country': ['Nepal', 'USA', 'UAE', 'India']}

# %%
df = pd.DataFrame(data1)

# %%
print(df)
# Out:
#       name  age country
# 0    Netra   30   Nepal
# 1    Kumar   25     USA
# 2  Shristi   33     UAE
# 3  Binayak   54   India

# %%
data = pd.read_csv("E:\Python\Pandas_Project\Data\data.csv")
print(data)
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 0      male          51         1             rarely
# 1    Female          55         2          sometimes
# 2      male          65         3             always
# 3    Female          79         4             rarely
# 4      male          67         1              often
# ..      ...         ...       ...                ...
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 0    interactive whiteboards,     yes        43               Android   17
# 1            educational apps     yes        41                   IOS   18
# 2            online platforms     yes        45               Windows   18
# ...

# %% [markdown]
# #Finding the Info of the Data

# %%
data.head() #First five Rows
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# 0     yes        43               Android   17   Metropolitan City      Hindu
# 1     yes        41                   IOS   18     Submetropolitan  Christian
# 2     yes        45               Windows   18        Municipality    Buddism
# 3      no        40                others   19  Rural Municipality     Muslim
# 4      no        44               Android   17   Metropolitan City      other

# %%
#Last Five Rows
data.tail()
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy             ICT_Tools  \
# 195  Female          68         5             always      online platforms
# 196    male          54         4              often      educational apps
# 197    male          72         2             always  multimedia resources
# 198  Female          52         1              often  multimedia resources
# 199    male          54         3             always  multimedia resources
#
#     TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area  \
# 195     yes        44                others   15   Metropolitan City
# 196      no        45               Android   14     Submetropolitan
# 197     yes        41                   IOS   20        Municipality
# 198      no        39               Windows   17  Rural Municipality
# 199     yes        37                others   18   Metropolitan City
#
#       Religion
# 195      other
# 196     Muslim
# 197      Hindu
# 198  Christian
# 199      other

# %%
#Certain Rows 
data.head(10)
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
# 5  Female          37         2          sometimes          educational apps
# 6  Female          36         3             rarely  interactive whiteboards,
# 7  Female          48         4             always          online platforms
# 8  Female          68         1          sometimes          educational apps
# 9  Female          72         3             always          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# ...

# %%
data.head(20)
# Out:
#     Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0     male          51         1             rarely  interactive whiteboards,
# 1   Female          55         2          sometimes          educational apps
# 2     male          65         3             always          online platforms
# 3   Female          79         4             rarely          online platforms
# 4     male          67         1              often          online platforms
# 5   Female          37         2          sometimes          educational apps
# 6   Female          36         3             rarely  interactive whiteboards,
# 7   Female          48         4             always          online platforms
# 8   Female          68         1          sometimes          educational apps
# 9   Female          72         3             always          online platforms
# 10    male          45         4              often          online platforms
# ...

# %%
data.tail(10)
# Out:
#      Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy  \
# 190    male          50         2              often
# 191  Female          70         4             always
# 192    male          50         2              often
# 193  Female          57         5             always
# 194    male          68         2              often
# 195  Female          68         5             always
# 196    male          54         4              often
# 197    male          72         2             always
# 198  Female          52         1              often
# 199    male          54         3             always
#
#                     ICT_Tools TPD_ICT  CS_Marks Operating_system_Used  Age  \
# 190          educational apps      no        37               Windows   15
# 191          online platforms     yes        43                others   14
# 192      multimedia resources      no        34               Android   12
# 193  interactive whiteboards,     yes        46                   IOS   15
# ...

# %%
data.info() #Finding the complete info of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Gender                 200 non-null    object
#  1   Marks_Math             200 non-null    int64
#  2   Time_ICT               200 non-null    int64
#  3   ICT_Based_Pedagogy     200 non-null    object
#  4   ICT_Tools              200 non-null    object
#  5   TPD_ICT                200 non-null    object
#  6   CS_Marks               200 non-null    int64
#  7   Operating_system_Used  200 non-null    object
#  8   Age                    200 non-null    int64
#  9   Residental_Area        200 non-null    object
#  10  Religion               200 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 17.3+ KB

# %%
#General Statistical information 
data.describe()
# Out:
#        Marks_Math    Time_ICT    CS_Marks         Age
# count  200.000000  200.000000  200.000000  200.000000
# mean    63.725000    3.355000   41.165000   14.900000
# std     11.799386    1.533209    3.168275    1.883544
# min     33.000000    1.000000   33.000000   12.000000
# 25%     56.000000    2.000000   39.000000   13.000000
# 50%     64.000000    3.000000   41.000000   15.000000
# 75%     72.000000    5.000000   43.000000   16.000000
# max     94.000000    7.000000   49.000000   20.000000

# %%
#Number of Rows and Columsn
data.shape #200 Rows and 11 Columns
# Out:
# (200, 11)

# %%
data.isnull().sum() #Check if the data has null value
# Out:
# Gender                   0
# Marks_Math               0
# Time_ICT                 0
# ICT_Based_Pedagogy       0
# ICT_Tools                0
# TPD_ICT                  0
# CS_Marks                 0
# Operating_system_Used    0
# Age                      0
# Residental_Area          0
# Religion                 0
# dtype: int64

# %%
#Indexing and Selecting data
data.head()
# Out:
#    Gender  Marks_Math  Time_ICT ICT_Based_Pedagogy                 ICT_Tools  \
# 0    male          51         1             rarely  interactive whiteboards,
# 1  Female          55         2          sometimes          educational apps
# 2    male          65         3             always          online platforms
# 3  Female          79         4             rarely          online platforms
# 4    male          67         1              often          online platforms
#
#   TPD_ICT  CS_Marks Operating_system_Used  Age     Residental_Area   Religion
# 0     yes        43               Android   17   Metropolitan City      Hindu
# 1     yes        41                   IOS   18     Submetropolitan  Christian
# 2     yes        45               Windows   18        Municipality    Buddism
# 3      no        40                others   19  Rural Municipality     Muslim
# 4      no        44               Android   17   Metropolitan City      other

# %%
data['Marks_Math'] #Selecting a single columns
# Out:
# 0      51
# 1      55
# 2      65
# 3      79
# 4      67
#        ..
# 195    68
# 196    54
# 197    72
# 198    52
# 199    54
# Name: Marks_Math, Length: 200, dtype: int64

# %%
#Selecting multiple columns
data_new = data[['Marks_Math', 'CS_Marks', 'ICT_Based_Pedagogy']]
print(data_new)
# Out:
#      Marks_Math  CS_Marks ICT_Based_Pedagogy
# 0            51        43             rarely
# 1            55        41          sometimes
# 2            65        45             always
# 3            79        40             rarely
# 4            67        44              often
# ..          ...       ...                ...
# 195          68        44             always
# 196          54        45              often
# 197          72        41             always
# 198          52        39              often
# 199          54        37             always
#
# [200 rows x 3 columns]

# %%
data.head(0) #Only Header
# Out:
# Empty DataFrame
# Columns: [Gender, Marks_Math, Time_ICT, ICT_Based_Pedagogy, ICT_Tools, TPD_ICT, CS_Marks, Operating_system_Used, Age, Residental_Area, Religion]
# Index: []

# %%
#Selecting Rows by Index 
a = data.loc[1] #By Label ---- Second Rows 
print(a)
# Out:
# Gender                             Female
# Marks_Math                             55
# Time_ICT                                2
# ICT_Based_Pedagogy              sometimes
# ICT_Tools                educational apps
# TPD_ICT                               yes
# CS_Marks                               41
# Operating_system_Used                 IOS
# Age                                    18
# Residental_Area           Submetropolitan
# Religion                        Christian
# Name: 1, dtype: object

# %%
b = data.loc[5] #Selects sixth row
print(b)
# Out:
# Gender                             Female
# Marks_Math                             37
# Time_ICT                                2
# ICT_Based_Pedagogy              sometimes
# ICT_Tools                educational apps
# TPD_ICT                               yes
# CS_Marks                               43
# Operating_system_Used                 IOS
# Age                                    16
# Residental_Area              Municipality
# Religion                            Hindu
# Name: 5, dtype: object

# %%
#By Position
data.iloc[2]
# Out:
# Gender                               male
# Marks_Math                             65
# Time_ICT                                3
# ICT_Based_Pedagogy                 always
# ICT_Tools                online platforms
# TPD_ICT                               yes
# CS_Marks                               45
# Operating_system_Used             Windows
# Age                                    18
# Residental_Area              Municipality
# Religion                          Buddism
# Name: 2, dtype: object

# %%
data.iloc[100]
# Out:
# Gender                                   male
# Marks_Math                                 44
# Time_ICT                                    4
# ICT_Based_Pedagogy                     rarely
# ICT_Tools                multimedia resources
# TPD_ICT                                   yes
# CS_Marks                                   40
# Operating_system_Used                 Windows
# Age                                        12
# Residental_Area            Rural Municipality
# Religion                                other
# Name: 100, dtype: object

# %%
#Statistical Values
mean_value = data['CS_Marks'].mean()
print(mean_value)
# Out:
# 41.165

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Gender, Marks_Math, Time_ICT, ICT_Based_Pedagogy, ICT_Tools, TPD_ICT, CS_Marks, Operating_system_Used, Age, Residental_Area, Religion]
# Index: []

# %%
#Multiple Mean Values
mean_values = data['Time_ICT'].mean()
print(mean_values)
# Out:
# 3.355

# %%
#Median Value
median_value = data['Age'].median()
print(median_value)
# Out:
# 15.0

# %%
median_value1 = data['Time_ICT'].median()
print(median_value1)
# Out:
# 3.0

# %%
#Mode Value
mode_value = data['Marks_Math'].mode()
print(mode_value)
# Out:
# 0    68
# Name: Marks_Math, dtype: int64

# %%
#Variance
variance = data['Marks_Math'].var()
print(variance)
# Out:
# 139.22550251256283

# %%
#Standard Deviation
std = data['Marks_Math'].std()
print(std)
# Out:
# 11.799385683693997

# %%
#Count and Sum
count_value = data['Age'].count()
sum_value = data['Age'].sum()
print(count_value)
print(sum_value)
# Out:
# 200
# 2980

# %%
#Minimum and Maximum 
min_value = data['Age'].min()
max_value = data['Age'].max()
print(min_value)
print(max_value)
# Out:
# 12
# 20

# %%
#Describe Method
data.describe()
# Out:
#        Marks_Math    Time_ICT    CS_Marks         Age
# count  200.000000  200.000000  200.000000  200.000000
# mean    63.725000    3.355000   41.165000   14.900000
# std     11.799386    1.533209    3.168275    1.883544
# min     33.000000    1.000000   33.000000   12.000000
# 25%     56.000000    2.000000   39.000000   13.000000
# 50%     64.000000    3.000000   41.000000   15.000000
# 75%     72.000000    5.000000   43.000000   16.000000
# max     94.000000    7.000000   49.000000   20.000000

# %%
#Correlation and and Covariance
correlation = data['CS_Marks'].corr(data['Time_ICT'])
print(correlation)
# Out:
# -0.0648775238326068

# %%
correlation2 = data['Marks_Math'].corr(data['Age'])
print(correlation2)
# Out:
# -0.10299119459031295

# %%
#Covariance
covariance = data['Marks_Math'].cov(data['CS_Marks'])
print(covariance)
# Out:
# 4.427512562814069

# %% [markdown]
# Data Manipulation

# %%
data.dtypes
# Out:
# Gender                   object
# Marks_Math                int64
# Time_ICT                  int64
# ICT_Based_Pedagogy       object
# ICT_Tools                object
# TPD_ICT                  object
# CS_Marks                  int64
# Operating_system_Used    object
# Age                       int64
# Residental_Area          object
# Religion                 object
# dtype: object

# %%
data[['Gender', 'Marks_Math', 'CS_Marks', 'Age', 'Time_ICT']].groupby('Gender').mean()
# Out:
#         Marks_Math   CS_Marks        Age  Time_ICT
# Gender
# Female   63.137255  41.147059  14.970588  3.411765
# male     64.336735  41.183673  14.826531  3.295918
